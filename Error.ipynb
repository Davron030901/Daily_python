# %% [markdown]
# <a href="https://colab.research.google.com/github/Davron030901/Daily_python/blob/main/Error.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###***Error***

# %% [markdown]
# ##1.Syntax  Error
# ##2.Semantic Error
# ##3.Run time Error
# ##4.Logical Error

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
try:
  c=int(input("Son kiriting: "))
  print(c)
except ValueError as e:
  print('Ma\'lumot turida xato',e)
else:
  print("Xatosiz ishladi.")
  # Do try, not do except
finally:
  print("Try/except ishladi")
# Out:
# Son kiriting: 4
# 4
# Xatosiz ishladi.
# Try/except ishladi

# %%
try:
  c=int(input("Son kiriting: "))
  print(c)
except Exception as e:
  print('Ma\'lumot turida xato',e)
  # don't know Errer type
else:
  print("Xatosiz ishladi.")
finally:
  print("Try/except ishladi")
  # running code
# Out:
# Son kiriting: jk
# Ma'lumot turida xato invalid literal for int() with base 10: 'jk'
# Try/except ishladi

# %%
try:
  function()
except NameError as e:
  print(e)
else:
  print("Xato yo'q")
finally:
  print("Kod ishladi")
# Out:
# name 'function' is not defined
# Kod ishladi
